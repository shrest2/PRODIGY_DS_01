# %% [markdown]
# # PRODIGY_DS_01

# %% [markdown]
# #### Task #1: Create a barchart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or gender in the population

# %%
#IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as pyp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#IMPORTING DATASET
df=pd.read_csv("C:/Users/HP/Desktop/Internship/Prodigy/world_population1.csv")

# %% [raw]
#  Overview Of the given Dataset

# %%
df
# Out:
#                                    Country Name Country Code  \
# 0                                         India          IND
# 1                                         China          CHN
# 2                            Sub-Saharan Africa          SSF
# 3     Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 4    Sub-Saharan Africa (excluding high income)          SSA
# ..                                          ...          ...
# 220                    St. Martin (French part)          MAF
# 221                      British Virgin Islands          VGB
# 222                                       Palau          PLW
# 223                                       Nauru          NRU
# 224                                      Tuvalu          TUV
#
#         Indicator Name Indicator Code         1960         1961         1962  \
# 0    Population, total    SP.POP.TOTL  445954579.0  456351876.0  467024193.0
# ...

# %%
df.head()
# Out:
#                                  Country Name Country Code     Indicator Name  \
# 0                                       India          IND  Population, total
# 1                                       China          CHN  Population, total
# 2                          Sub-Saharan Africa          SSF  Population, total
# 3   Sub-Saharan Africa (IDA & IBRD countries)          TSS  Population, total
# 4  Sub-Saharan Africa (excluding high income)          SSA  Population, total
#
#   Indicator Code         1960         1961         1962         1963  \
# 0    SP.POP.TOTL  445954579.0  456351876.0  467024193.0  477933619.0
# 1    SP.POP.TOTL  667070000.0  660330000.0  665770000.0  682335000.0
# 2    SP.POP.TOTL  227948869.0  233483265.0  239280622.0  245298063.0
# 3    SP.POP.TOTL  227948869.0  233483265.0  239280622.0  245298063.0
# 4    SP.POP.TOTL  227907169.0  233440376.0  239236580.0  245252887.0
#
#           1964         1965  ...        2013        2014        2015  \
# ...

# %%
df.shape
# Out:
# (225, 67)

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018                int64
# 2019                int64
# 2020                int64
# 2021                int64
# 2022                int64
# Length: 67, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    225 non-null    object
#  1   Country Code    225 non-null    object
#  2   Indicator Name  225 non-null    object
#  3   Indicator Code  225 non-null    object
#  4   1960            224 non-null    float64
#  5   1961            224 non-null    float64
#  6   1962            224 non-null    float64
#  7   1963            224 non-null    float64
#  8   1964            224 non-null    float64
#  9   1965            224 non-null    float64
#  10  1966            224 non-null    float64
#  11  1967            224 non-null    float64
#  12  1968            224 non-null    float64
#  13  1969            224 non-null    float64
#  14  1970            224 non-null    float64
#  15  1971            224 non-null    float64
#  16  1972            224 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              1
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# Length: 67, dtype: int64

# %% [markdown]
# #####  Categorization and Visualisation Using Seaborn and Matplotlib

# %%
sns.barplot(x='Country Name', y='2022', data=df)

# %%
df = pd.DataFrame(df)
Continent = df['Country Code']
pop = df['2022']
pyp.bar(Continent, pop, width=0.25, color="green")
pyp.show()

# %% [raw]
# From the above graph we see the diagrammatic representation of population for the year of 2022. We see that India has the highest population growth for the year 2022.
